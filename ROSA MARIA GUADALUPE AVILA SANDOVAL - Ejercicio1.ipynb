# %% [markdown]
# **Ejercicios para verificar los temas de expresiones y variables.**
#
# Realice lo siguiente:
#
# Escribir su nombre y su código en una celda de texto al inicio del documento de google colab.
#
# **Ejercicio 1:**
#
# Agregue una celda de código y en una variable guarde una cadena en la cual describa su motivación para estudiar la carrera de computación. Hecho esto realice lo siguiente:
#
# *   Imprima en pantalla a la frase completa.
# *   Duplique la frase por medio de una operación de repetición e imprima en pantalla.
# *   Concatene la frase " Gracias por su atención. " al final de su frase e imprima en pantalla.
#
# **Ejercicio 2:**
#
# Declare dos variables (Ej. A = 14 y B = 50.98) con valores de tipo entero o real y realice lo siguiente:
#
# *   Sume ambas variables e imprima el resultado.
# *   Reste ambas variables e imprima el resultado.
# *   Multiplique ambas variables e imprima el resultado.
# *   Divida ambas variables e imprima el resultado.
# *   Divida por medio de la división de piso a ambas variables e imprima el resultado.
# *   Saque el módulo e imprima el resultado.
# *   Eleve a ambas variables a la potencia 3 e imprima el resultado.
#
# **Ejercicio 3:**
#
# Tome las variables declaradas en el ejercicio 2, realice las siguientes comparaciones e imprima el resultado en pantalla:
#
# *   Variable 1 igual a Variable 2
# *   Variable 1 diferente a Variable 2
# *   Variable 2 mayor que Variable 1
# *   Variable 2 menor que Variable 1
# *   Variable 1 mayor o igual que Variable 2
# *   Variable 1 menor o igual que Variable 2
#
# **Ejercicio 4:**
#
# Tome las variables declaradas en el ejercicio 2 y realice lo siguiente e imprima el resultado en pantalla:
#
#
#
# *   **no**(V1 - 5 >= V2 + 9 **y** V2 != V1)
# *   (V2 x 5 < V1 / 3) **o** **no**(V1 == V2 potencia 2)
#
# **Nota:** Separe cada ejercicio en una celda de código distinta y agregue una celda de texto que indique el nombre del ejercicio.

# %% [markdown]
# Avila Sandoval Rosa Maria Guadalupe
# Código: 218419793

# %% [markdown]
# **Ejercicio 1**

# %%
#ejercicio 1
motivo = "elegí esta carrera ya que en la prepa estaba asistiendo a unas asesorias de programación para competir en una olimpiada y me di cuenta de que se me facilitaba la programación y además me gustaba, además desde niña me ha gustado todo lo de tecnología y una meta que tengo es un día poder programar un videojuego \n"

#indicación 1
print(motivo)

#indicación 2
print(motivo*2)

#Concatenar
print(motivo + "Gracias por su  atención. ")
# Out:
# elegí esta carrera ya que en la prepa estaba asistiendo a unas asesorias de programación para competir en una olimpiada y me di cuenta de que se me facilitaba la programación y además me gustaba, además desde niña me ha gustado todo lo de tecnología y una meta que tengo es un día poder programar un videojuego
#
# elegí esta carrera ya que en la prepa estaba asistiendo a unas asesorias de programación para competir en una olimpiada y me di cuenta de que se me facilitaba la programación y además me gustaba, además desde niña me ha gustado todo lo de tecnología y una meta que tengo es un día poder programar un videojuego
# elegí esta carrera ya que en la prepa estaba asistiendo a unas asesorias de programación para competir en una olimpiada y me di cuenta de que se me facilitaba la programación y además me gustaba, además desde niña me ha gustado todo lo de tecnología y una meta que tengo es un día poder programar un videojuego
#
# elegí esta carrera ya que en la prepa estaba asistiendo a unas asesorias de programación para competir en una olimpiada y me di cuenta de que se me facilitaba la programación y además me gustaba, además desde niña me ha gustado todo lo de tecnología y una meta que tengo es un día poder programar un videojuego
# Gracias por su  atención.

# %% [markdown]
# **Ejercicio 2**

# %%
#ejercicio 2
Ent =27
Deci= 11.23

#suma
print("Suma:",Ent + Deci )

#Resta
print("Resta:",Ent - Deci)

#multiplicación
print("Multiplicación:", Ent * Deci)

#División 
print("División:", Ent / Deci)

#División de piso
print("División de piso:", Ent // Deci)

#Modulo
print("Modulo:",Ent % Deci)

#Potencias (tenia duda si eran las dos en un solo print o aparte, por eso lo hice de las 2 forma)
print("Potencias: ")
print(Ent**3)
print(Deci**3)
print(Ent**3, Deci**3)

#NOTA: Le puse el nombre de la operación correspondiente aunque no lo haya indicado 
#para que a la hora de imprimir se viera en mejor orden los resultados ya que son muchos números
# Out:
# Suma: 38.230000000000004
# Resta: 15.77
# Multiplicación: 303.21000000000004
# División: 2.404274265360641
# División de piso: 2.0
# Modulo: 4.539999999999999
# Potencias:
# 19683
# 1416.2478670000003
# 19683 1416.2478670000003

# %% [markdown]
# **Ejercicio 3**

# %%
#Ejercico 3
Ent=27
Deci= 11.23

#igual
print(Ent == Deci)

#diferente
print(Ent != Deci)

#mayor
print(Deci> Ent)

#menor
print(Deci<Ent)

#Mayor igual
print(Ent >= Deci)

#menor igual
print(Ent <= Deci)

#NOTA: a este codigo no le agregué texto a la hora de imprimir para que quede como otra alternativa
#diferente al codigo anterior que si puse texto al imprimir.
# Out:
# False
# True
# False
# True
# True
# False

# %% [markdown]
# **Ejercicio 4**

# %%
#ejercicio 4
Ent=27
Deci= 11.23

Nega = ( not (Ent - 5 >= Deci + 9 and Deci != Ent))

print(Nega)

Comp = ((Deci * 5 < Ent / 3) or (Ent == Deci ** 2))

print(Comp)
# Out:
# False
# False
