# %% [markdown]
# # **Tema 2.2: Sentencias Selectivas**

# %% [markdown]
# # **Ejemplo 1**
#
# ---
#
#
#
# > Realice un algoritmo para determinar si un número es positivo o negativo.
#
#
# ## **Variables de entrada y salida**
# ![image.png](data:image/png;base64,...)
#
# # **Pseudocódigo**
#
#
# ```
# 1. Inicio.
# 2. Leer NÚM
# 3. Si NÚM > = 0
#       Hacer R = “POSITIVO”
#    Si no
#       Hacer R = “NEGATIVO”
# 4. Escribir “el número es”, R
# 5. Fin
# ```
# # **Diagrama de flujo**
# ![image.png](data:image/png;base64,...)

# %%
#Código Ejemplo 1 Número Negativo

Num = int(input("Ingresa un número: "))

if Num >= 0:
  R = "Positivo"
else:
  R = "Negativo"

print("\nEl número ingresado es: ", R)
# Out:
# Ingresa un número: -11
#
# El número ingresado es:  Negativo

# %% [markdown]
# # **Ejemplo 2**
#
# ---
#
#
# > Realice un algoritmo para determinar cuánto se debe pagar por cierta cantidad de lápices considerando que si son 1000 o más el costo es de 85¢; de lo contrario, el precio es de 90¢.
#
#
#
# # **Variables de entrada y salida**
# ![image.png](data:image/png;base64,...)
# # **Pseudocódigo**
#
# ```
# 1. Inicio
# 2. Leer X
# 3. Si X > = 1000
#       Hacer PAG = X * 0.85
#    Si no
#       Hacer PAG = X * 0.90
# 4. Escribir “el pago es”, PAG
# 5. Fin
# ```
#
# # **Diagrama de flujo**
#
# ![image.png](data:image/png;base64,...)

# %%
#Código Ejemplo 2 Pago por lápices

X = int(input("Ingrese la cantidad de lápices a llevar: "))

if X >= 1000:
  PAG = X * 0.85
else:
  PAG = X * 0.90

print("\nEl pago total por esa cantidad de lápices es: ", PAG)
# Out:
# Ingrese la cantidad de lápices a llevar: 1000
#
# El pago total por esa cantidad de lápices es:  850.0

# %% [markdown]
# # **Ejemplo 3**
#
# ---
#
# > “La langosta ahumada” es una empresa dedicada a ofrecer banquetes; sus tarifas son las siguientes: el costo de platillo por persona es de 95.00, pero si el número de personas es mayor a 200 pero menor o igual a 300, el costo es de 85.00. Para más de 300 personas el costo por platillo es de 75.00. Se requiere un algoritmo que ayude a determinar el presupuesto que se debe presentar a los clientes que deseen realizar un evento.
#
#
#
# # **Variables de entrada y salida**
# ![image.png](data:image/png;base64,...)
# # **Pseudocódigo**
#
#
# ```
# 1. Inicio
# 2. Leer NP
# 3. Si NP > 300
#       Hacer TOT = NP * 75
#    Si no
#       Si NP > 200
#           Hacer TOT = NP * 85
#       Si no
#           Hacer TOT = NP * 95
# 4. Escribir “El total es”, TOT
# 5. Fin
# ```
#
#
# # **Diagrama de Flujo**
# ![image.png](data:image/png;base64,...)

# %%
#Código Ejemplo 3: Presupuesto Banquete

NP = int(input("Ingrese el número total de personas: "))

if NP > 300:
  TOT = NP*75.00
else:
  if NP > 200:
    TOT = NP * 85.00
  else:
    TOT = NP * 95.00

print("El precio total por {} personas es: ${} pesos".format(NP, TOT))
# Out:
# Ingrese el número total de personas: 100
# El precio total por 100 personas es: $9500.0 pesos

# %% [markdown]
# # **Ejercicio 1**
#
# ---
#
#
#
#
# > Realice un programa que solicite la edad (Dato de tipo entero) de una persona y determine si es niño, adolescente, adulto o anciano, según el siguiente rango de edades:
#
#
# *   0 a 12 años imprimir Es niño
# *   13 a 17 años imprimir Es adolescente
# *   18 a 80 años imprimir Es adulto
# *   Mayor que 80 imprimir Es anciano
#
# > **Nota:** Utilice una estructura if - elif - else para realizar este ejercicio.

# %%
#edad
Años = int(input("Ingrese su edad: "))

if Años >= 0 and Años < 115:
 if Años <= 12:
   print("\nEs niño.")
 elif Años >=13 and Años<=17:
   print("\nEs adolescente.")
 elif Años>= 18 and Años<= 80:
   print("\nEs adulto.")
 elif Años >= 80:
   print("\nEs ansiano.")
else: 
    print("\nDato no válido.")
# Out:
# Ingrese su edad: 93
# Es ansiano.

# %% [markdown]
# # **Ejercicio 2**
#
# ---
#
#
#
# > Realice un algoritmo que, con base en un número proporcionado
# (1-7), indique el día de la semana que le corresponde (L-D).

# %%
#Semana

num = int(input("Ingrese un número del 1 al 7: "))

if num >= 1 and num<=  7:
  if num == 1:
    print("\nEl día correspondiente a ese número es Lunes.")
  elif num == 2:
    print("\nEl día correspondiente a ese número es Martes.")
  elif num == 3:
    print("\nEl día correspondiente a ese número es Miércoles.")
  elif num == 4:
    print("\nEl día correspondiente a ese número es Jueves.")
  elif num== 5:
    print("\nEl día correspondiente a ese número es Viernes.")
  elif num == 6:
    print("\nEl día correspondiente a ese número Sábado.")
  elif num == 7:
    print("\nEl día correspondiente a ese número es Domingo.")
else: 
  print("Dato no válido.")
# Out:
# Ingrese un número del 1 al 7: 5
#
# El día correspondiente a ese número es Viernes.

# %% [markdown]
# # **Ejercicio 3**
#
# ---
#
#
#
# > Realice un algoritmo para determinar qué paquete se puede comprar una persona con el dinero de su aguinaldo, considerando lo siguiente:
#
#
# *   **Paquete A.** Si recibe $50,000 o más se comprará una televisión, un modular, tres pares de zapatos, cinco camisas y cinco pantalones.
#
# *  **Paquete B.** Si recibe menos de 50,000 pero más (o igual) de
# $20,000, se comprará una grabadora, tres pares de zapatos, cinco camisas y cinco pantalones.
#
# *  **Paquete C.** Si recibe menos de 20,000 pero más (o igual) de
# 10,000, se comprará dos pares de zapatos, tres camisas y tres
# pantalones.
#
# *  **Paquete D.** Si recibe menos de $10,000, se tendrá que conformar con un par de zapatos, dos camisas y dos pantalones.

# %%
#Paquetes

dinero = int(input("Ingrese la cantidad de dinero de su aguinaldo para determinar que paquete puede comprar: "))

if dinero >=2000 and dinero<= 100000:
  if dinero >= 50000:
    print("\nUsted puede comprar el paquete A que es: una televisión, un modular, tres pares de zapatos, cinco camisas y cinco pantalones.")
  elif dinero <50000 and dinero>=20000:
    print("\nUsted puede comprar el paquete B que es: una grabadora, tres pares de zapatos, cinco camisas y cinco pantalones.")
  elif dinero <20000 and dinero >=10000:
    print("\nUsted puede comprar el paquete C que es: dos pares de zapatos, tres camisas y tres pantalones.")
  elif dinero <10000:
    print("\nUsted puede comprar el paquete D que es: un par de zapatos, dos camisas y dos pantalones.")
else:
  print("\nDato no válido.")
# Out:
# Ingrese la cantidad de dinero de su aguinaldo para determinar que paquete puede comprar: 35870
#
# Usted puede comprar el paquete B que es: una grabadora, tres pares de zapatos, cinco camisas y cinco pantalones.
